# %% [markdown]
# Exploratory analysis over AC10 experiments

# %%
import pandas as pd

# %%
df = pd.read_csv("ac10_wandb.csv")
df_focus = df[["Name", "Created", "learning_rate", "lr_warmup_steps", "max_train_steps", "adam_beta2", "adam_weight_decay"]]

df_focus.sort_values(by='Created', inplace = True)
#df_focus = df_focus.iloc[::-1].reset_index(drop=True)
#display(df_focus)

# Swap index around
new_index = list(reversed(df_focus.index))
# Set the new index
df_focus.index = new_index

# df_focus = df_focus.drop([15, 18])
# Swap index around
new_index = list((df_focus.index))
# Set the new index
df_focus.index = new_index

df_adam = df_focus.iloc[24:]

display(df_adam.drop(["Created"], axis=1))

df_adam.to_csv("ac10_exp_overview_adam.csv")
# Out:
# /tmp/ipykernel_4092/3924544079.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_focus.sort_values(by='Created', inplace = True)
#                                                  Name  learning_rate  \
# 24  audiocaps-10%-lora-sd1_5-lr5e4-25epochs+28kwar...         0.0005
# 25  audiocaps-10%-lora-sd1_5-lr7e4-25epochs+28kwar...         0.0007
# 26  audiocaps-10%-lora-sd1_5-lr7e4-25epochs+28kwar...         0.0007
# 27  audiocaps-10%-lora-sd1_5-lr5e4-25epochs+28kwar...         0.0005
# 28  audiocaps-10%-lora-sd1_5-lr5e4-25epochs+28kwar...         0.0005
# 29  audiocaps-10%-lora-sd1_5-lr7e4-25epochs+28kwar...         0.0007
# 30  audiocaps-10%-lora-sd1_5-lr7e4-25epochs+28kwar...         0.0007
# 31  audiocaps-10%-lora-sd1_5-lr5e4-25epochs+28kwar...         0.0005
# ...

# %%
print(df_focus["learning_rate"].value_counts())
print(df_focus["learning_rate"].value_counts())
# Out:
# learning_rate
# 0.00010    9
# 0.00050    9
# 0.00070    9
# 0.00100    8
# 0.00300    6
# 0.00030    3
# 0.00001    1
# Name: count, dtype: int64

# %%
df_full = pd.read_csv("acfull_wandb.csv")
df_full = df_full[["Name", "Created", "learning_rate", "lr_warmup_steps", "max_train_steps", "adam_beta2", "adam_weight_decay"]]

df_full.sort_values(by='Created', inplace = True)
#df_focus = df_focus.iloc[::-1].reset_index(drop=True)
#display(df_focus)

# Swap index around
new_index = list(reversed(df_full.index))
# Set the new index
df_full.index = new_index

# df_focus = df_focus.drop([15, 18])
# Swap index around
new_index = list((df_full.index))
# Set the new index
df_full.index = new_index

#df_adam = df_focus.iloc[24:]

display(df_full.drop(["Created"], axis=1))

df_full.to_csv("acfull_exp_overview_1.csv")
# Out:
#                                                 Name  learning_rate  \
# 1  audiocaps-full-lora-sd1_5-lr3e4-25epochs+20%wa...         0.0003
# 5  audiocaps-full-lora-sd1_5-lr1e4-25epochs+20%wa...         0.0001
# 0  audiocaps-full-lora-sd1_5-lr3e3-25epochs+20%wa...         0.0030
# 4  audiocaps-full-lora-sd1_5-lr7e4-25epochs+20%wa...         0.0007
# 3  audiocaps-full-lora-sd1_5-lr5e4-25epochs+20%wa...         0.0005
# 2  audiocaps-full-lora-sd1_5-lr1e3-25epochs+20%wa...         0.0010
#
#    lr_warmup_steps  max_train_steps  adam_beta2  adam_weight_decay
# 1           125000           752000       0.999               0.01
# 5           125000           752000       0.999               0.01
# 0           125000           752000       0.999               0.01
# 4           125000           752000       0.999               0.01
# 3           125000           752000       0.999               0.01
# 2           125000           752000       0.999               0.01
