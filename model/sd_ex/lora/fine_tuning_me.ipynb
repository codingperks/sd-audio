# %%
# Load model
from diffusers import StableDiffusionPipeline

repo_id = model_name
pipe = StableDiffusionPipeline.from_pretrained(repo_id)
# Out:
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.

# %%
from datasets import load_dataset

dataset = load_dataset("imagefolder", data_dir="./ryan_perkins")
# Out:
# Downloading and preparing dataset imagefolder/default to /home/ryan/.cache/huggingface/datasets/imagefolder/default-2852ff3adacd7c18/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f...
# Downloading data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset imagefolder downloaded and prepared to /home/ryan/.cache/huggingface/datasets/imagefolder/default-2852ff3adacd7c18/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Run training script
# !export MODEL_NAME="runwayml/stable-diffusion-v1-5"
# !export DATASET_NAME="./ryan_perkins"
# !export OUTPUT_DIR="./out"

# !accelerate launch --mixed_precision="fp16"  train_text_to_image_lora.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5" \
  --dataset_name="lambdalabs/pokemon-blip-captions" \
  --dataloader_num_workers=8 \
  --resolution=512 --center_crop --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=15000 \
  --learning_rate=1e-04 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" --lr_warmup_steps=0 \
  --output_dir=$"./out" \
  --report_to=wandb \
  --checkpointing_steps=500 \
  --seed=1337
# Out:
# [2023-06-16 15:50:17,144] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2023-06-16 15:50:19,162] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/accelerate/utils/dataclasses.py:589: UserWarning: DeepSpeed Zero3 Init flag is only applicable for ZeRO Stage 3. Setting it to False.
#   warnings.warn("DeepSpeed Zero3 Init flag is only applicable for ZeRO Stage 3. Setting it to False.")
# [2023-06-16 15:50:20,236] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [2023-06-16 15:50:20,236] [INFO] [comm.py:594:init_distributed] cdb=None
# [2023-06-16 15:50:20,236] [INFO] [comm.py:625:init_distributed] Initializing TorchBackend in DeepSpeed with backend nccl
# 06/16/2023 15:50:20 - INFO - __main__ - Distributed environment: DEEPSPEED  Backend: nccl
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda:0
#
# Mixed precision type: fp16
# ds_config: {'train_batch_size': 'auto', 'train_micro_batch_size_per_gpu': 'auto', 'gradient_accumulation_steps': 1, 'zero_optimization': {'stage': 2, 'offload_optimizer': {'device': 'cpu', 'nvme_path': None}, 'offload_param': {'device': 'cpu', 'nvme_path': None}, 'stage3_gather_16bit_weights_on_model_save': False}, 'steps_per_print': inf, 'fp16': {'enabled': True, 'auto_cast': True}, 'bf16': {'enabled': False}}
#
# {'prediction_type', 'dynamic_thresholding_ratio', 'variance_type', 'sample_max_value', 'clip_sample_range', 'thresholding'} was not found in config. Values will be initialized to default values.
# {'scaling_factor'} was not found in config. Values will be initialized to default values.
# {'conv_out_kernel', 'cross_attention_norm', 'mid_block_type', 'time_cond_proj_dim', 'resnet_time_scale_shift', 'resnet_skip_time_act', 'only_cross_attention', 'class_embeddings_concat', 'use_linear_projection', 'mid_block_only_cross_attention', 'encoder_hid_dim_type', 'dual_cross_attention', 'addition_embed_type_num_heads', 'conv_in_kernel', 'projection_class_embeddings_input_dim', 'resnet_out_scale_factor', 'upcast_attention', 'timestep_post_act', 'time_embedding_act_fn', 'addition_embed_type', 'time_embedding_type', 'num_class_embeds', 'class_embed_type', 'encoder_hid_dim', 'time_embedding_dim'} was not found in config. Values will be initialized to default values.
# Downloading metadata: 100%|████████████████████| 731/731 [00:00<00:00, 7.72MB/s]
# Downloading readme: 100%|██████████████████| 1.80k/1.80k [00:00<00:00, 24.3MB/s]
# Downloading and preparing dataset imagefolder/pokemon (download: 95.05 MiB, generated: 113.89 MiB, post-processed: Unknown size, total: 208.94 MiB) to /home/ryan/.cache/huggingface/datasets/lambdalabs___parquet/lambdalabs--pokemon-blip-captions-10e3527a764857bd/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7...
# Downloading data files:   0%|                             | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|                             | 0.00/99.7M [00:00<?, ?B/s]
# Downloading data:   3%|▋                   | 3.37M/99.7M [00:00<00:02, 33.7MB/s]
# Downloading data:  11%|██▏                 | 10.6M/99.7M [00:00<00:01, 56.4MB/s]
# Downloading data:  16%|███▎                | 16.2M/99.7M [00:00<00:01, 55.0MB/s]
# Downloading data:  24%|████▋               | 23.6M/99.7M [00:00<00:01, 62.3MB/s]
# Downloading data:  30%|██████              | 30.0M/99.7M [00:00<00:01, 62.6MB/s]
# Downloading data:  36%|███████▎            | 36.2M/99.7M [00:00<00:01, 60.4MB/s]
# Downloading data:  43%|████████▋           | 43.3M/99.7M [00:00<00:00, 63.7MB/s]
# Downloading data:  50%|█████████▉          | 49.7M/99.7M [00:00<00:00, 61.3MB/s]
# Downloading data:  57%|███████████▍        | 56.8M/99.7M [00:00<00:00, 64.2MB/s]
# Downloading data:  63%|████████████▋       | 63.3M/99.7M [00:01<00:00, 62.8MB/s]
# Downloading data:  70%|██████████████      | 70.0M/99.7M [00:01<00:00, 64.1MB/s]
# Downloading data:  77%|███████████████▎    | 76.4M/99.7M [00:01<00:00, 61.4MB/s]
# Downloading data:  84%|████████████████▊   | 83.6M/99.7M [00:01<00:00, 64.4MB/s]
# Downloading data:  90%|██████████████████  | 90.1M/99.7M [00:01<00:00, 61.8MB/s]
# Downloading data: 100%|████████████████████| 99.7M/99.7M [00:01<00:00, 61.8MB/s]
# Downloading data files: 100%|█████████████████████| 1/1 [00:02<00:00,  2.40s/it]
# Extracting data files: 100%|████████████████████| 1/1 [00:00<00:00, 2183.40it/s]
# Dataset parquet downloaded and prepared to /home/ryan/.cache/huggingface/datasets/lambdalabs___parquet/lambdalabs--pokemon-blip-captions-10e3527a764857bd/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7. Subsequent calls will reuse this data.
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1419.39it/s]
# Using /home/ryan/.cache/torch_extensions/py310_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ryan/.cache/torch_extensions/py310_cu118/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 2.2042384147644043 seconds
# Adam Optimizer #0 is created with AVX2 arithmetic capability.
# Config: alpha=0.000100, betas=(0.900000, 0.999000), weight_decay=0.010000, adam_w=1
# [2023-06-16 15:50:32,007] [INFO] [logging.py:96:log_dist] [Rank 0] DeepSpeed info: version=0.9.4, git-hash=unknown, git-branch=unknown
# 06/16/2023 15:50:32 - INFO - torch.distributed.distributed_c10d - Added key: store_based_barrier_key:2 to store for rank: 0
# 06/16/2023 15:50:32 - INFO - torch.distributed.distributed_c10d - Rank 0: Completed store-based barrier for key:store_based_barrier_key:2 with 1 nodes.
# [2023-06-16 15:50:32,042] [INFO] [logging.py:96:log_dist] [Rank 0] DeepSpeed Flops Profiler Enabled: False
# [2023-06-16 15:50:32,042] [INFO] [logging.py:96:log_dist] [Rank 0] Removing param_group that has no 'params' in the client Optimizer
# [2023-06-16 15:50:32,042] [INFO] [logging.py:96:log_dist] [Rank 0] Using client Optimizer as basic optimizer
# [2023-06-16 15:50:32,048] [INFO] [logging.py:96:log_dist] [Rank 0] DeepSpeed Basic Optimizer = DeepSpeedCPUAdam
# [2023-06-16 15:50:32,048] [INFO] [utils.py:54:is_zero_supported_optimizer] Checking ZeRO support for optimizer=DeepSpeedCPUAdam type=<class 'deepspeed.ops.adam.cpu_adam.DeepSpeedCPUAdam'>
# [2023-06-16 15:50:32,048] [INFO] [logging.py:96:log_dist] [Rank 0] Creating torch.float16 ZeRO stage 2 optimizer
# [2023-06-16 15:50:32,048] [INFO] [stage_1_and_2.py:133:__init__] Reduce bucket size 500,000,000
# [2023-06-16 15:50:32,048] [INFO] [stage_1_and_2.py:134:__init__] Allgather bucket size 500,000,000
# [2023-06-16 15:50:32,048] [INFO] [stage_1_and_2.py:135:__init__] CPU Offload: True
# [2023-06-16 15:50:32,048] [INFO] [stage_1_and_2.py:136:__init__] Round robin gradient partitioning: False
# Using /home/ryan/.cache/torch_extensions/py310_cu118 as PyTorch extensions root...
# Emitting ninja build file /home/ryan/.cache/torch_extensions/py310_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.07422757148742676 seconds
# Rank: 0 partition count [1] and sizes[(797184, False)]
# [2023-06-16 15:50:32,233] [INFO] [utils.py:785:see_memory_usage] Before initializing optimizer states
# [2023-06-16 15:50:32,233] [INFO] [utils.py:786:see_memory_usage] MA 2.02 GB         Max_MA 2.02 GB         CA 2.03 GB         Max_CA 2 GB
# [2023-06-16 15:50:32,233] [INFO] [utils.py:793:see_memory_usage] CPU Virtual Memory:  used = 5.6 GB, percent = 36.0%
# [2023-06-16 15:50:32,328] [INFO] [utils.py:785:see_memory_usage] After initializing optimizer states
# [2023-06-16 15:50:32,329] [INFO] [utils.py:786:see_memory_usage] MA 2.02 GB         Max_MA 2.02 GB         CA 2.03 GB         Max_CA 2 GB
# [2023-06-16 15:50:32,329] [INFO] [utils.py:793:see_memory_usage] CPU Virtual Memory:  used = 5.61 GB, percent = 36.1%
# [2023-06-16 15:50:32,329] [INFO] [stage_1_and_2.py:489:__init__] optimizer state initialized
# [2023-06-16 15:50:32,414] [INFO] [utils.py:785:see_memory_usage] After initializing ZeRO optimizer
# [2023-06-16 15:50:32,414] [INFO] [utils.py:786:see_memory_usage] MA 2.02 GB         Max_MA 2.02 GB         CA 2.03 GB         Max_CA 2 GB
# [2023-06-16 15:50:32,415] [INFO] [utils.py:793:see_memory_usage] CPU Virtual Memory:  used = 5.61 GB, percent = 36.1%
# [2023-06-16 15:50:32,419] [INFO] [logging.py:96:log_dist] [Rank 0] DeepSpeed Final Optimizer = DeepSpeedCPUAdam
# [2023-06-16 15:50:32,420] [INFO] [logging.py:96:log_dist] [Rank 0] DeepSpeed using client LR scheduler
# [2023-06-16 15:50:32,420] [INFO] [logging.py:96:log_dist] [Rank 0] DeepSpeed LR Scheduler = None
# [2023-06-16 15:50:32,420] [INFO] [logging.py:96:log_dist] [Rank 0] step=0, skipped=0, lr=[0.0001], mom=[(0.9, 0.999)]
# [2023-06-16 15:50:32,420] [INFO] [config.py:960:print] DeepSpeedEngine configuration:
# [2023-06-16 15:50:32,420] [INFO] [config.py:964:print]   activation_checkpointing_config  {
#     "partition_activations": false,
#     "contiguous_memory_optimization": false,
#     "cpu_checkpointing": false,
#     "number_checkpoints": null,
#     "synchronize_checkpoint_boundary": false,
#     "profile": false
# }
# [2023-06-16 15:50:32,420] [INFO] [config.py:964:print]   aio_config ................... {'block_size': 1048576, 'queue_depth': 8, 'thread_count': 1, 'single_submit': False, 'overlap_events': True}
# [2023-06-16 15:50:32,420] [INFO] [config.py:964:print]   amp_enabled .................. False
# [2023-06-16 15:50:32,420] [INFO] [config.py:964:print]   amp_params ................... False
# [2023-06-16 15:50:32,420] [INFO] [config.py:964:print]   autotuning_config ............ {
#     "enabled": false,
#     "start_step": null,
#     "end_step": null,
#     "metric_path": null,
#     "arg_mappings": null,
#     "metric": "throughput",
#     "model_info": null,
#     "results_dir": "autotuning_results",
#     "exps_dir": "autotuning_exps",
#     "overwrite": true,
#     "fast": true,
#     "start_profile_step": 3,
#     "end_profile_step": 5,
#     "tuner_type": "gridsearch",
#     "tuner_early_stopping": 5,
#     "tuner_num_trials": 50,
#     "model_info_path": null,
#     "mp_size": 1,
#     "max_train_batch_size": null,
#     "min_train_batch_size": 1,
#     "max_train_micro_batch_size_per_gpu": 1.024000e+03,
#     "min_train_micro_batch_size_per_gpu": 1,
#     "num_tuning_micro_batch_sizes": 3
# }
# [2023-06-16 15:50:32,420] [INFO] [config.py:964:print]   bfloat16_enabled ............. False
# [2023-06-16 15:50:32,420] [INFO] [config.py:964:print]   checkpoint_parallel_write_pipeline  False
# [2023-06-16 15:50:32,420] [INFO] [config.py:964:print]   checkpoint_tag_validation_enabled  True
# [2023-06-16 15:50:32,420] [INFO] [config.py:964:print]   checkpoint_tag_validation_fail  False
# [2023-06-16 15:50:32,420] [INFO] [config.py:964:print]   comms_config ................. <deepspeed.comm.config.DeepSpeedCommsConfig object at 0x7fb190123370>
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   communication_data_type ...... None
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   compression_config ........... {'weight_quantization': {'shared_parameters': {'enabled': False, 'quantizer_kernel': False, 'schedule_offset': 0, 'quantize_groups': 1, 'quantize_verbose': False, 'quantization_type': 'symmetric', 'quantize_weight_in_forward': False, 'rounding': 'nearest', 'fp16_mixed_quantize': False, 'quantize_change_ratio': 0.001}, 'different_groups': {}}, 'activation_quantization': {'shared_parameters': {'enabled': False, 'quantization_type': 'symmetric', 'range_calibration': 'dynamic', 'schedule_offset': 1000}, 'different_groups': {}}, 'sparse_pruning': {'shared_parameters': {'enabled': False, 'method': 'l1', 'schedule_offset': 1000}, 'different_groups': {}}, 'row_pruning': {'shared_parameters': {'enabled': False, 'method': 'l1', 'schedule_offset': 1000}, 'different_groups': {}}, 'head_pruning': {'shared_parameters': {'enabled': False, 'method': 'topk', 'schedule_offset': 1000}, 'different_groups': {}}, 'channel_pruning': {'shared_parameters': {'enabled': False, 'method': 'l1', 'schedule_offset': 1000}, 'different_groups': {}}, 'layer_reduction': {'enabled': False}}
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   curriculum_enabled_legacy .... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   curriculum_params_legacy ..... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   data_efficiency_config ....... {'enabled': False, 'seed': 1234, 'data_sampling': {'enabled': False, 'num_epochs': 1000, 'num_workers': 0, 'curriculum_learning': {'enabled': False}}, 'data_routing': {'enabled': False, 'random_ltd': {'enabled': False, 'layer_token_lr_schedule': {'enabled': False}}}}
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   data_efficiency_enabled ...... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   dataloader_drop_last ......... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   disable_allgather ............ False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   dump_state ................... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   dynamic_loss_scale_args ...... None
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   eigenvalue_enabled ........... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   eigenvalue_gas_boundary_resolution  1
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   eigenvalue_layer_name ........ bert.encoder.layer
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   eigenvalue_layer_num ......... 0
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   eigenvalue_max_iter .......... 100
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   eigenvalue_stability ......... 1e-06
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   eigenvalue_tol ............... 0.01
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   eigenvalue_verbose ........... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   elasticity_enabled ........... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   flops_profiler_config ........ {
#     "enabled": false,
#     "recompute_fwd_factor": 0.0,
#     "profile_step": 1,
#     "module_depth": -1,
#     "top_modules": 1,
#     "detailed": true,
#     "output_file": null
# }
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   fp16_auto_cast ............... True
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   fp16_enabled ................. True
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   fp16_master_weights_and_gradients  False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   global_rank .................. 0
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   grad_accum_dtype ............. None
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   gradient_accumulation_steps .. 1
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   gradient_clipping ............ 0.0
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   gradient_predivide_factor .... 1.0
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   hybrid_engine ................ enabled=False max_out_tokens=512 inference_tp_size=1 release_inference_cache=False pin_parameters=True tp_gather_partition_size=8
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   initial_dynamic_scale ........ 65536
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   load_universal_checkpoint .... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   loss_scale ................... 0
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   memory_breakdown ............. False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   mics_hierarchial_params_gather  False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   mics_shard_size .............. -1
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   monitor_config ............... tensorboard=TensorBoardConfig(enabled=False, output_path='', job_name='DeepSpeedJobName') wandb=WandbConfig(enabled=False, group=None, team=None, project='deepspeed') csv_monitor=CSVConfig(enabled=False, output_path='', job_name='DeepSpeedJobName') enabled=False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   nebula_config ................ {
#     "enabled": false,
#     "persistent_storage_path": null,
#     "persistent_time_interval": 100,
#     "num_of_version_in_retention": 2,
#     "enable_nebula_load": true,
#     "load_path": null
# }
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   optimizer_legacy_fusion ...... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   optimizer_name ............... None
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   optimizer_params ............. None
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   pipeline ..................... {'stages': 'auto', 'partition': 'best', 'seed_layers': False, 'activation_checkpoint_interval': 0}
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   pld_enabled .................. False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   pld_params ................... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   prescale_gradients ........... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   scheduler_name ............... None
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   scheduler_params ............. None
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   sparse_attention ............. None
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   sparse_gradients_enabled ..... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   steps_per_print .............. inf
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   train_batch_size ............. 1
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   train_micro_batch_size_per_gpu  1
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   use_node_local_storage ....... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   wall_clock_breakdown ......... False
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   world_size ................... 1
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   zero_allow_untested_optimizer  True
# [2023-06-16 15:50:32,421] [INFO] [config.py:964:print]   zero_config .................. stage=2 contiguous_gradients=True reduce_scatter=True reduce_bucket_size=500,000,000 allgather_partitions=True allgather_bucket_size=500,000,000 overlap_comm=False load_from_fp32_weights=True elastic_checkpoint=False offload_param=DeepSpeedZeroOffloadParamConfig(device='cpu', nvme_path=None, buffer_count=5, buffer_size=100,000,000, max_in_cpu=1,000,000,000, pin_memory=False) offload_optimizer=DeepSpeedZeroOffloadOptimizerConfig(device='cpu', nvme_path=None, buffer_count=4, pin_memory=False, pipeline=False, pipeline_read=False, pipeline_write=False, fast_init=False) sub_group_size=1,000,000,000 cpu_offload_param=None cpu_offload_use_pin_memory=None cpu_offload=None prefetch_bucket_size=50,000,000 param_persistence_threshold=100,000 model_persistence_threshold=sys.maxsize max_live_parameters=1,000,000,000 max_reuse_distance=1,000,000,000 gather_16bit_weights_on_model_save=False stage3_gather_fp16_weights_on_model_save=False ignore_unused_parameters=True legacy_stage1=False round_robin_gradients=False mics_shard_size=-1 mics_hierarchical_params_gather=False memory_efficient_linear=True
# [2023-06-16 15:50:32,422] [INFO] [config.py:964:print]   zero_enabled ................. True
# [2023-06-16 15:50:32,422] [INFO] [config.py:964:print]   zero_force_ds_cpu_optimizer .. True
# [2023-06-16 15:50:32,422] [INFO] [config.py:964:print]   zero_optimization_stage ...... 2
# [2023-06-16 15:50:32,422] [INFO] [config.py:950:print_user_config]   json = {
#     "train_batch_size": 1,
#     "train_micro_batch_size_per_gpu": 1,
#     "gradient_accumulation_steps": 1,
#     "zero_optimization": {
#         "stage": 2,
#         "offload_optimizer": {
#             "device": "cpu",
#             "nvme_path": null
#         },
#         "offload_param": {
#             "device": "cpu",
#             "nvme_path": null
#         },
#         "stage3_gather_16bit_weights_on_model_save": false
#     },
#     "steps_per_print": inf,
#     "fp16": {
#         "enabled": true,
#         "auto_cast": true
#     },
#     "bf16": {
#         "enabled": false
#     },
#     "zero_allow_untested_optimizer": true
# }
# Using /home/ryan/.cache/torch_extensions/py310_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002040863037109375 seconds
# wandb: Currently logged in as: rap. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /home/ryan/diss/msc_diss/sdspeech/model/sd_ex/lora/wandb/run-20230616_155033-gmytjhpi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run wild-thunder-1
# wandb: ⭐️ View project at https://wandb.ai/rap/text2image-fine-tune
# wandb: 🚀 View run at https://wandb.ai/rap/text2image-fine-tune/runs/gmytjhpi
# 06/16/2023 15:50:36 - INFO - __main__ - ***** Running training *****
# 06/16/2023 15:50:36 - INFO - __main__ -   Num examples = 833
# 06/16/2023 15:50:36 - INFO - __main__ -   Num Epochs = 72
# 06/16/2023 15:50:36 - INFO - __main__ -   Instantaneous batch size per device = 1
# 06/16/2023 15:50:36 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 4
# 06/16/2023 15:50:36 - INFO - __main__ -   Gradient Accumulation steps = 4
# 06/16/2023 15:50:36 - INFO - __main__ -   Total optimization steps = 15000
# Steps:   0%|                                          | 0/15000 [00:00<?, ?it/s][2023-06-16 15:50:38,905] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 4294967296, reducing to 2147483648
# Steps:   0%|   | 1/15000 [00:01<8:10:54,  1.96s/it, lr=0.0001, step_loss=0.0076][2023-06-16 15:50:39,083] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 2147483648, reducing to 1073741824
# Steps:   0%|   | 2/15000 [00:02<3:48:21,  1.09it/s, lr=0.0001, step_loss=0.0231][2023-06-16 15:50:39,252] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 1073741824, reducing to 536870912
# Steps:   0%|    | 3/15000 [00:02<2:23:18,  1.74it/s, lr=0.0001, step_loss=0.129][2023-06-16 15:50:39,419] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 536870912, reducing to 268435456
# Steps:   0%|  | 4/15000 [00:02<1:43:15,  2.42it/s, lr=0.0001, step_loss=0.00711][2023-06-16 15:50:39,586] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 268435456, reducing to 134217728
# Steps:   0%|   | 5/15000 [00:02<1:21:02,  3.08it/s, lr=0.0001, step_loss=0.0644][2023-06-16 15:50:39,752] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 134217728, reducing to 67108864
# Steps:   0%|   | 6/15000 [00:02<1:07:36,  3.70it/s, lr=0.0001, step_loss=0.0178][2023-06-16 15:50:39,919] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 67108864, reducing to 33554432
# Steps:   0%|      | 7/15000 [00:02<59:06,  4.23it/s, lr=0.0001, step_loss=0.234][2023-06-16 15:50:40,086] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 33554432, reducing to 16777216
# Steps:   0%|    | 10/15000 [00:03<47:57,  5.21it/s, lr=0.0001, step_loss=0.0303][2023-06-16 15:50:40,597] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 16777216, reducing to 8388608
# Steps:   0%|    | 15/15000 [00:04<43:51,  5.69it/s, lr=0.0001, step_loss=0.0555][2023-06-16 15:50:41,460] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 8388608, reducing to 4194304
# Steps:   3%|   | 419/15000 [01:14<42:20,  5.74it/s, lr=0.0001, step_loss=0.0386][2023-06-16 15:51:51,713] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 4194304, reducing to 2097152
# Steps:   3%|  | 500/15000 [01:28<42:08,  5.73it/s, lr=0.0001, step_loss=0.00547]06/16/2023 15:52:05 - INFO - accelerate.accelerator - Saving current state to ./out/checkpoint-500
# 06/16/2023 15:52:05 - INFO - accelerate.accelerator - Saving DeepSpeed Model and Optimizer
# [2023-06-16 15:52:05,713] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint pytorch_model is about to be saved!
# /home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# [2023-06-16 15:52:05,720] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: ./out/checkpoint-500/pytorch_model/mp_rank_00_model_states.pt
# [2023-06-16 15:52:05,720] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-500/pytorch_model/mp_rank_00_model_states.pt...
# [2023-06-16 15:52:05,726] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-500/pytorch_model/mp_rank_00_model_states.pt.
# [2023-06-16 15:52:05,726] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2023-06-16 15:52:05,733] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2023-06-16 15:52:05,733] [INFO] [engine.py:3245:_save_zero_checkpoint] zero checkpoint saved ./out/checkpoint-500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2023-06-16 15:52:05,733] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint pytorch_model is ready now!
# 06/16/2023 15:52:05 - INFO - accelerate.accelerator - DeepSpeed Model and Optimizer saved to output dir ./out/checkpoint-500/pytorch_model
# 06/16/2023 15:52:05 - INFO - accelerate.checkpointing - Scheduler state saved in ./out/checkpoint-500/scheduler.bin
# 06/16/2023 15:52:05 - INFO - accelerate.checkpointing - Random states saved in ./out/checkpoint-500/random_states_0.pkl
# 06/16/2023 15:52:05 - INFO - __main__ - Saved state to ./out/checkpoint-500
# Steps:   7%| | 1000/15000 [02:56<40:59,  5.69it/s, lr=9.99e-5, step_loss=0.0348]06/16/2023 15:53:33 - INFO - accelerate.accelerator - Saving current state to ./out/checkpoint-1000
# 06/16/2023 15:53:33 - INFO - accelerate.accelerator - Saving DeepSpeed Model and Optimizer
# [2023-06-16 15:53:33,930] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint pytorch_model is about to be saved!
# [2023-06-16 15:53:33,934] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: ./out/checkpoint-1000/pytorch_model/mp_rank_00_model_states.pt
# [2023-06-16 15:53:33,934] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-1000/pytorch_model/mp_rank_00_model_states.pt...
# [2023-06-16 15:53:33,940] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-1000/pytorch_model/mp_rank_00_model_states.pt.
# [2023-06-16 15:53:33,940] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-1000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2023-06-16 15:53:33,946] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-1000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2023-06-16 15:53:33,946] [INFO] [engine.py:3245:_save_zero_checkpoint] zero checkpoint saved ./out/checkpoint-1000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2023-06-16 15:53:33,946] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint pytorch_model is ready now!
# 06/16/2023 15:53:33 - INFO - accelerate.accelerator - DeepSpeed Model and Optimizer saved to output dir ./out/checkpoint-1000/pytorch_model
# 06/16/2023 15:53:33 - INFO - accelerate.checkpointing - Scheduler state saved in ./out/checkpoint-1000/scheduler.bin
# 06/16/2023 15:53:33 - INFO - accelerate.checkpointing - Random states saved in ./out/checkpoint-1000/random_states_0.pkl
# 06/16/2023 15:53:33 - INFO - __main__ - Saved state to ./out/checkpoint-1000
# Steps:  10%| | 1500/15000 [04:24<39:25,  5.71it/s, lr=9.98e-5, step_loss=0.0025206/16/2023 15:55:01 - INFO - accelerate.accelerator - Saving current state to ./out/checkpoint-1500
# 06/16/2023 15:55:01 - INFO - accelerate.accelerator - Saving DeepSpeed Model and Optimizer
# [2023-06-16 15:55:01,833] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint pytorch_model is about to be saved!
# [2023-06-16 15:55:01,837] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: ./out/checkpoint-1500/pytorch_model/mp_rank_00_model_states.pt
# [2023-06-16 15:55:01,837] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-1500/pytorch_model/mp_rank_00_model_states.pt...
# [2023-06-16 15:55:01,843] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-1500/pytorch_model/mp_rank_00_model_states.pt.
# [2023-06-16 15:55:01,843] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-1500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2023-06-16 15:55:01,849] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-1500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2023-06-16 15:55:01,850] [INFO] [engine.py:3245:_save_zero_checkpoint] zero checkpoint saved ./out/checkpoint-1500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2023-06-16 15:55:01,850] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint pytorch_model is ready now!
# 06/16/2023 15:55:01 - INFO - accelerate.accelerator - DeepSpeed Model and Optimizer saved to output dir ./out/checkpoint-1500/pytorch_model
# 06/16/2023 15:55:01 - INFO - accelerate.checkpointing - Scheduler state saved in ./out/checkpoint-1500/scheduler.bin
# 06/16/2023 15:55:01 - INFO - accelerate.checkpointing - Random states saved in ./out/checkpoint-1500/random_states_0.pkl
# 06/16/2023 15:55:01 - INFO - __main__ - Saved state to ./out/checkpoint-1500
# Steps:  13%|▏| 1951/15000 [05:44<38:10,  5.70it/s, lr=9.97e-5, step_loss=0.00255[2023-06-16 15:56:22,032] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 4194304, reducing to 2097152
# Steps:  13%|▎ | 2000/15000 [05:53<38:00,  5.70it/s, lr=9.97e-5, step_loss=0.033]06/16/2023 15:56:30 - INFO - accelerate.accelerator - Saving current state to ./out/checkpoint-2000
# 06/16/2023 15:56:30 - INFO - accelerate.accelerator - Saving DeepSpeed Model and Optimizer
# [2023-06-16 15:56:30,461] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint pytorch_model is about to be saved!
# [2023-06-16 15:56:30,465] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: ./out/checkpoint-2000/pytorch_model/mp_rank_00_model_states.pt
# [2023-06-16 15:56:30,465] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-2000/pytorch_model/mp_rank_00_model_states.pt...
# [2023-06-16 15:56:30,471] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-2000/pytorch_model/mp_rank_00_model_states.pt.
# [2023-06-16 15:56:30,471] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-2000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2023-06-16 15:56:30,478] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-2000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2023-06-16 15:56:30,478] [INFO] [engine.py:3245:_save_zero_checkpoint] zero checkpoint saved ./out/checkpoint-2000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2023-06-16 15:56:30,478] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint pytorch_model is ready now!
# 06/16/2023 15:56:30 - INFO - accelerate.accelerator - DeepSpeed Model and Optimizer saved to output dir ./out/checkpoint-2000/pytorch_model
# 06/16/2023 15:56:30 - INFO - accelerate.checkpointing - Scheduler state saved in ./out/checkpoint-2000/scheduler.bin
# 06/16/2023 15:56:30 - INFO - accelerate.checkpointing - Random states saved in ./out/checkpoint-2000/random_states_0.pkl
# 06/16/2023 15:56:30 - INFO - __main__ - Saved state to ./out/checkpoint-2000
# Steps:  17%|▏| 2500/15000 [07:22<1:12:11,  2.89it/s, lr=9.96e-5, step_loss=0.13306/16/2023 15:57:59 - INFO - accelerate.accelerator - Saving current state to ./out/checkpoint-2500
# 06/16/2023 15:57:59 - INFO - accelerate.accelerator - Saving DeepSpeed Model and Optimizer
# [2023-06-16 15:57:59,304] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint pytorch_model is about to be saved!
# [2023-06-16 15:57:59,310] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: ./out/checkpoint-2500/pytorch_model/mp_rank_00_model_states.pt
# [2023-06-16 15:57:59,310] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-2500/pytorch_model/mp_rank_00_model_states.pt...
# [2023-06-16 15:57:59,318] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-2500/pytorch_model/mp_rank_00_model_states.pt.
# [2023-06-16 15:57:59,319] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-2500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2023-06-16 15:57:59,327] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-2500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2023-06-16 15:57:59,327] [INFO] [engine.py:3245:_save_zero_checkpoint] zero checkpoint saved ./out/checkpoint-2500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2023-06-16 15:57:59,327] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint pytorch_model is ready now!
# 06/16/2023 15:57:59 - INFO - accelerate.accelerator - DeepSpeed Model and Optimizer saved to output dir ./out/checkpoint-2500/pytorch_model
# 06/16/2023 15:57:59 - INFO - accelerate.checkpointing - Scheduler state saved in ./out/checkpoint-2500/scheduler.bin
# 06/16/2023 15:57:59 - INFO - accelerate.checkpointing - Random states saved in ./out/checkpoint-2500/random_states_0.pkl
# 06/16/2023 15:57:59 - INFO - __main__ - Saved state to ./out/checkpoint-2500
# Steps:  20%|▏| 3000/15000 [08:50<35:12,  5.68it/s, lr=9.94e-5, step_loss=0.0254]06/16/2023 15:59:27 - INFO - accelerate.accelerator - Saving current state to ./out/checkpoint-3000
# 06/16/2023 15:59:27 - INFO - accelerate.accelerator - Saving DeepSpeed Model and Optimizer
# [2023-06-16 15:59:27,558] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint pytorch_model is about to be saved!
# [2023-06-16 15:59:27,562] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: ./out/checkpoint-3000/pytorch_model/mp_rank_00_model_states.pt
# [2023-06-16 15:59:27,562] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-3000/pytorch_model/mp_rank_00_model_states.pt...
# [2023-06-16 15:59:27,568] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-3000/pytorch_model/mp_rank_00_model_states.pt.
# [2023-06-16 15:59:27,568] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-3000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2023-06-16 15:59:27,574] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-3000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2023-06-16 15:59:27,574] [INFO] [engine.py:3245:_save_zero_checkpoint] zero checkpoint saved ./out/checkpoint-3000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2023-06-16 15:59:27,574] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint pytorch_model is ready now!
# 06/16/2023 15:59:27 - INFO - accelerate.accelerator - DeepSpeed Model and Optimizer saved to output dir ./out/checkpoint-3000/pytorch_model
# 06/16/2023 15:59:27 - INFO - accelerate.checkpointing - Scheduler state saved in ./out/checkpoint-3000/scheduler.bin
# 06/16/2023 15:59:27 - INFO - accelerate.checkpointing - Random states saved in ./out/checkpoint-3000/random_states_0.pkl
# 06/16/2023 15:59:27 - INFO - __main__ - Saved state to ./out/checkpoint-3000
# Steps:  23%|▏| 3500/15000 [10:19<33:44,  5.68it/s, lr=9.92e-5, step_loss=0.0659]06/16/2023 16:00:56 - INFO - accelerate.accelerator - Saving current state to ./out/checkpoint-3500
# 06/16/2023 16:00:56 - INFO - accelerate.accelerator - Saving DeepSpeed Model and Optimizer
# [2023-06-16 16:00:56,449] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint pytorch_model is about to be saved!
# [2023-06-16 16:00:56,454] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: ./out/checkpoint-3500/pytorch_model/mp_rank_00_model_states.pt
# [2023-06-16 16:00:56,454] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-3500/pytorch_model/mp_rank_00_model_states.pt...
# [2023-06-16 16:00:56,460] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-3500/pytorch_model/mp_rank_00_model_states.pt.
# [2023-06-16 16:00:56,460] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-3500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2023-06-16 16:00:56,467] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-3500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2023-06-16 16:00:56,467] [INFO] [engine.py:3245:_save_zero_checkpoint] zero checkpoint saved ./out/checkpoint-3500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2023-06-16 16:00:56,467] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint pytorch_model is ready now!
# 06/16/2023 16:00:56 - INFO - accelerate.accelerator - DeepSpeed Model and Optimizer saved to output dir ./out/checkpoint-3500/pytorch_model
# 06/16/2023 16:00:56 - INFO - accelerate.checkpointing - Scheduler state saved in ./out/checkpoint-3500/scheduler.bin
# 06/16/2023 16:00:56 - INFO - accelerate.checkpointing - Random states saved in ./out/checkpoint-3500/random_states_0.pkl
# 06/16/2023 16:00:56 - INFO - __main__ - Saved state to ./out/checkpoint-3500
# Steps:  25%|▏| 3737/15000 [11:01<33:03,  5.68it/s, lr=9.91e-5, step_loss=0.0152][2023-06-16 16:01:38,485] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 4194304, reducing to 2097152
# Steps:  27%|▎| 4000/15000 [11:47<32:19,  5.67it/s, lr=9.89e-5, step_loss=0.0036]06/16/2023 16:02:24 - INFO - accelerate.accelerator - Saving current state to ./out/checkpoint-4000
# 06/16/2023 16:02:24 - INFO - accelerate.accelerator - Saving DeepSpeed Model and Optimizer
# [2023-06-16 16:02:24,659] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint pytorch_model is about to be saved!
# [2023-06-16 16:02:24,663] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: ./out/checkpoint-4000/pytorch_model/mp_rank_00_model_states.pt
# [2023-06-16 16:02:24,663] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-4000/pytorch_model/mp_rank_00_model_states.pt...
# [2023-06-16 16:02:24,669] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-4000/pytorch_model/mp_rank_00_model_states.pt.
# [2023-06-16 16:02:24,669] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-4000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2023-06-16 16:02:24,676] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-4000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2023-06-16 16:02:24,676] [INFO] [engine.py:3245:_save_zero_checkpoint] zero checkpoint saved ./out/checkpoint-4000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2023-06-16 16:02:24,676] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint pytorch_model is ready now!
# 06/16/2023 16:02:24 - INFO - accelerate.accelerator - DeepSpeed Model and Optimizer saved to output dir ./out/checkpoint-4000/pytorch_model
# 06/16/2023 16:02:24 - INFO - accelerate.checkpointing - Scheduler state saved in ./out/checkpoint-4000/scheduler.bin
# 06/16/2023 16:02:24 - INFO - accelerate.checkpointing - Random states saved in ./out/checkpoint-4000/random_states_0.pkl
# 06/16/2023 16:02:24 - INFO - __main__ - Saved state to ./out/checkpoint-4000
# Steps:  30%|▎| 4500/15000 [13:16<30:58,  5.65it/s, lr=9.86e-5, step_loss=0.0242]06/16/2023 16:03:53 - INFO - accelerate.accelerator - Saving current state to ./out/checkpoint-4500
# 06/16/2023 16:03:53 - INFO - accelerate.accelerator - Saving DeepSpeed Model and Optimizer
# [2023-06-16 16:03:53,813] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint pytorch_model is about to be saved!
# [2023-06-16 16:03:53,817] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: ./out/checkpoint-4500/pytorch_model/mp_rank_00_model_states.pt
# [2023-06-16 16:03:53,817] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-4500/pytorch_model/mp_rank_00_model_states.pt...
# [2023-06-16 16:03:53,823] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-4500/pytorch_model/mp_rank_00_model_states.pt.
# [2023-06-16 16:03:53,823] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-4500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2023-06-16 16:03:53,830] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-4500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2023-06-16 16:03:53,830] [INFO] [engine.py:3245:_save_zero_checkpoint] zero checkpoint saved ./out/checkpoint-4500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2023-06-16 16:03:53,830] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint pytorch_model is ready now!
# 06/16/2023 16:03:53 - INFO - accelerate.accelerator - DeepSpeed Model and Optimizer saved to output dir ./out/checkpoint-4500/pytorch_model
# 06/16/2023 16:03:53 - INFO - accelerate.checkpointing - Scheduler state saved in ./out/checkpoint-4500/scheduler.bin
# 06/16/2023 16:03:53 - INFO - accelerate.checkpointing - Random states saved in ./out/checkpoint-4500/random_states_0.pkl
# 06/16/2023 16:03:53 - INFO - __main__ - Saved state to ./out/checkpoint-4500
# Steps:  33%|▎| 5000/15000 [14:45<49:55,  3.34it/s, lr=9.83e-5, step_loss=0.0969]06/16/2023 16:05:22 - INFO - accelerate.accelerator - Saving current state to ./out/checkpoint-5000
# 06/16/2023 16:05:22 - INFO - accelerate.accelerator - Saving DeepSpeed Model and Optimizer
# [2023-06-16 16:05:22,696] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint pytorch_model is about to be saved!
# [2023-06-16 16:05:22,700] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: ./out/checkpoint-5000/pytorch_model/mp_rank_00_model_states.pt
# [2023-06-16 16:05:22,700] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-5000/pytorch_model/mp_rank_00_model_states.pt...
# [2023-06-16 16:05:22,706] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-5000/pytorch_model/mp_rank_00_model_states.pt.
# [2023-06-16 16:05:22,707] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-5000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2023-06-16 16:05:22,713] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-5000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2023-06-16 16:05:22,713] [INFO] [engine.py:3245:_save_zero_checkpoint] zero checkpoint saved ./out/checkpoint-5000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2023-06-16 16:05:22,713] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint pytorch_model is ready now!
# 06/16/2023 16:05:22 - INFO - accelerate.accelerator - DeepSpeed Model and Optimizer saved to output dir ./out/checkpoint-5000/pytorch_model
# 06/16/2023 16:05:22 - INFO - accelerate.checkpointing - Scheduler state saved in ./out/checkpoint-5000/scheduler.bin
# 06/16/2023 16:05:22 - INFO - accelerate.checkpointing - Random states saved in ./out/checkpoint-5000/random_states_0.pkl
# 06/16/2023 16:05:22 - INFO - __main__ - Saved state to ./out/checkpoint-5000
# Steps:  37%|▋ | 5500/15000 [16:14<27:55,  5.67it/s, lr=9.8e-5, step_loss=0.0159]06/16/2023 16:06:51 - INFO - accelerate.accelerator - Saving current state to ./out/checkpoint-5500
# 06/16/2023 16:06:51 - INFO - accelerate.accelerator - Saving DeepSpeed Model and Optimizer
# [2023-06-16 16:06:51,208] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint pytorch_model is about to be saved!
# [2023-06-16 16:06:51,212] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: ./out/checkpoint-5500/pytorch_model/mp_rank_00_model_states.pt
# [2023-06-16 16:06:51,212] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-5500/pytorch_model/mp_rank_00_model_states.pt...
# [2023-06-16 16:06:51,218] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-5500/pytorch_model/mp_rank_00_model_states.pt.
# [2023-06-16 16:06:51,218] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-5500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2023-06-16 16:06:51,224] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-5500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# [2023-06-16 16:06:51,225] [INFO] [engine.py:3245:_save_zero_checkpoint] zero checkpoint saved ./out/checkpoint-5500/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt
# [2023-06-16 16:06:51,225] [INFO] [torch_checkpoint_engine.py:33:commit] [Torch] Checkpoint pytorch_model is ready now!
# 06/16/2023 16:06:51 - INFO - accelerate.accelerator - DeepSpeed Model and Optimizer saved to output dir ./out/checkpoint-5500/pytorch_model
# 06/16/2023 16:06:51 - INFO - accelerate.checkpointing - Scheduler state saved in ./out/checkpoint-5500/scheduler.bin
# 06/16/2023 16:06:51 - INFO - accelerate.checkpointing - Random states saved in ./out/checkpoint-5500/random_states_0.pkl
# 06/16/2023 16:06:51 - INFO - __main__ - Saved state to ./out/checkpoint-5500
# Steps:  38%|▍| 5763/15000 [17:00<27:19,  5.63it/s, lr=9.78e-5, step_loss=0.0652][2023-06-16 16:07:37,926] [INFO] [loss_scaler.py:183:update_scale] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 8388608, reducing to 4194304
# Steps:  40%|▍| 6000/15000 [17:43<26:33,  5.65it/s, lr=9.76e-5, step_loss=0.0246]06/16/2023 16:08:20 - INFO - accelerate.accelerator - Saving current state to ./out/checkpoint-6000
# 06/16/2023 16:08:20 - INFO - accelerate.accelerator - Saving DeepSpeed Model and Optimizer
# [2023-06-16 16:08:20,369] [INFO] [logging.py:96:log_dist] [Rank 0] [Torch] Checkpoint pytorch_model is about to be saved!
# [2023-06-16 16:08:20,373] [INFO] [logging.py:96:log_dist] [Rank 0] Saving model checkpoint: ./out/checkpoint-6000/pytorch_model/mp_rank_00_model_states.pt
# [2023-06-16 16:08:20,373] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-6000/pytorch_model/mp_rank_00_model_states.pt...
# [2023-06-16 16:08:20,379] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-6000/pytorch_model/mp_rank_00_model_states.pt.
# [2023-06-16 16:08:20,380] [INFO] [torch_checkpoint_engine.py:21:save] [Torch] Saving ./out/checkpoint-6000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt...
# [2023-06-16 16:08:20,386] [INFO] [torch_checkpoint_engine.py:23:save] [Torch] Saved ./out/checkpoint-6000/pytorch_model/zero_pp_rank_0_mp_rank_00_optim_states.pt.
# ...
#
# Downloading model.safetensors:  85%|█████▉ | 1.03G/1.22G [00:16<00:03, 61.2MB/s]
#
# Downloading model.safetensors:  85%|█████▉ | 1.04G/1.22G [00:16<00:02, 63.2MB/s]
#
# Downloading model.safetensors:  86%|██████ | 1.05G/1.22G [00:16<00:02, 61.2MB/s]
#
# Downloading model.safetensors:  87%|██████ | 1.06G/1.22G [00:17<00:02, 62.3MB/s]
#
# Downloading model.safetensors:  88%|██████▏| 1.07G/1.22G [00:17<00:02, 63.3MB/s]
#
# Downloading model.safetensors:  89%|██████▏| 1.08G/1.22G [00:17<00:02, 61.8MB/s]
#
# Downloading model.safetensors:  90%|██████▎| 1.09G/1.22G [00:17<00:01, 63.1MB/s]
#
# Downloading model.safetensors:  91%|██████▎| 1.10G/1.22G [00:17<00:01, 61.5MB/s]
#
# Downloading model.safetensors:  91%|██████▍| 1.11G/1.22G [00:17<00:01, 63.1MB/s]
#
# Downloading model.safetensors:  92%|██████▍| 1.12G/1.22G [00:18<00:01, 61.2MB/s]
#
# Downloading model.safetensors:  93%|██████▌| 1.13G/1.22G [00:18<00:01, 62.7MB/s]
#
# Downloading model.safetensors:  94%|██████▌| 1.14G/1.22G [00:18<00:01, 61.4MB/s]
#
# Downloading model.safetensors:  95%|██████▋| 1.15G/1.22G [00:18<00:01, 61.9MB/s]
#
# Downloading model.safetensors:  96%|██████▋| 1.16G/1.22G [00:18<00:00, 63.5MB/s]
#
# Downloading model.safetensors:  97%|██████▊| 1.17G/1.22G [00:19<00:00, 61.4MB/s]
#
# Downloading model.safetensors:  97%|██████▊| 1.18G/1.22G [00:19<00:00, 63.4MB/s]
#
# Downloading model.safetensors:  98%|██████▉| 1.20G/1.22G [00:19<00:00, 63.1MB/s]
#
# Downloading model.safetensors:  99%|██████▉| 1.21G/1.22G [00:19<00:00, 62.2MB/s]
#
# Downloading model.safetensors: 100%|███████| 1.22G/1.22G [00:19<00:00, 61.8MB/s]
#
# Fetching 15 files: 100%|████████████████████████| 15/15 [00:19<00:00,  1.33s/it]
# {'requires_safety_checker'} was not found in config. Values will be initialized to default values.
# {'prediction_type'} was not found in config. Values will be initialized to default values.
# {'conv_out_kernel', 'cross_attention_norm', 'mid_block_type', 'time_cond_proj_dim', 'resnet_time_scale_shift', 'resnet_skip_time_act', 'only_cross_attention', 'class_embeddings_concat', 'use_linear_projection', 'mid_block_only_cross_attention', 'encoder_hid_dim_type', 'dual_cross_attention', 'addition_embed_type_num_heads', 'conv_in_kernel', 'projection_class_embeddings_input_dim', 'resnet_out_scale_factor', 'upcast_attention', 'timestep_post_act', 'time_embedding_act_fn', 'addition_embed_type', 'time_embedding_type', 'num_class_embeds', 'class_embed_type', 'encoder_hid_dim', 'time_embedding_dim'} was not found in config. Values will be initialized to default values.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# {'scaling_factor'} was not found in config. Values will be initialized to default values.
# Traceback (most recent call last):
#   File "/home/ryan/diss/msc_diss/sdspeech/model/sd_ex/lora/train_text_to_image_lora.py", line 939, in <module>
#     main()
#   File "/home/ryan/diss/msc_diss/sdspeech/model/sd_ex/lora/train_text_to_image_lora.py", line 917, in main
#     images.append(pipeline(args.validation_prompt, num_inference_steps=30, generator=generator).images[0])
#   File "/home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/diffusers/pipelines/stable_diffusion/pipeline_stable_diffusion.py", line 666, in __call__
#     self.check_inputs(
#   File "/home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/diffusers/pipelines/stable_diffusion/pipeline_stable_diffusion.py", line 527, in check_inputs
#     raise ValueError(
# ValueError: Provide either `prompt` or `prompt_embeds`. Cannot leave both `prompt` and `prompt_embeds` undefined.
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/ryan/diss/msc_diss/sdspeech/model/sd_ex/lora/train_text_to_image_lora. │
# │ py:939 in <module>                                                           │
# │                                                                              │
# │   936                                                                        │
# │   937                                                                        │
# │   938 if __name__ == "__main__":                                             │
# │ ❱ 939 │   main()                                                             │
# │   940                                                                        │
# │                                                                              │
# │ /home/ryan/diss/msc_diss/sdspeech/model/sd_ex/lora/train_text_to_image_lora. │
# │ py:917 in main                                                               │
# │                                                                              │
# │   914 │   │   generator = generator.manual_seed(args.seed)                   │
# │   915 │   images = []                                                        │
# │   916 │   for _ in range(args.num_validation_images):                        │
# │ ❱ 917 │   │   images.append(pipeline(args.validation_prompt, num_inference_s │
# │   918 │                                                                      │
# │   919 │   if accelerator.is_main_process:                                    │
# │   920 │   │   for tracker in accelerator.trackers:                           │
# │                                                                              │
# │ /home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/torch/utils │
# │ /_contextlib.py:115 in decorate_context                                      │
# │                                                                              │
# │   112 │   @functools.wraps(func)                                             │
# │   113 │   def decorate_context(*args, **kwargs):                             │
# │   114 │   │   with ctx_factory():                                            │
# │ ❱ 115 │   │   │   return func(*args, **kwargs)                               │
# │   116 │                                                                      │
# │   117 │   return decorate_context                                            │
# │   118                                                                        │
# │                                                                              │
# │ /home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/diffusers/p │
# │ ipelines/stable_diffusion/pipeline_stable_diffusion.py:666 in __call__       │
# │                                                                              │
# │   663 │   │   width = width or self.unet.config.sample_size * self.vae_scale │
# │   664 │   │                                                                  │
# │   665 │   │   # 1. Check inputs. Raise error if not correct                  │
# │ ❱ 666 │   │   self.check_inputs(                                             │
# │   667 │   │   │   prompt, height, width, callback_steps, negative_prompt, pr │
# │   668 │   │   )                                                              │
# │   669                                                                        │
# │                                                                              │
# │ /home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/diffusers/p │
# │ ipelines/stable_diffusion/pipeline_stable_diffusion.py:527 in check_inputs   │
# │                                                                              │
# │   524 │   │   │   │   " only forward one of the two."                        │
# │   525 │   │   │   )                                                          │
# │   526 │   │   elif prompt is None and prompt_embeds is None:                 │
# │ ❱ 527 │   │   │   raise ValueError(                                          │
# │   528 │   │   │   │   "Provide either `prompt` or `prompt_embeds`. Cannot le │
# │   529 │   │   │   )                                                          │
# │   530 │   │   elif prompt is not None and (not isinstance(prompt, str) and n │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ValueError: Provide either `prompt` or `prompt_embeds`. Cannot leave both
# `prompt` and `prompt_embeds` undefined.
# wandb: Waiting for W&B process to finish... (failed 1). Press Control-C to abort syncing.
# wandb:
# wandb: Run history:
# wandb: train_loss ▂▂█▂▃▃▂▂▁▂▂▂▃▂▃▂▂▂▂▁▁▁▁▃▃▂▁▃▄▁▁▁▁▂▁▂▁▁▂▂
# wandb:
# wandb: Run summary:
# wandb: train_loss 0.0025
# wandb:
# wandb: 🚀 View run wild-thunder-1 at: https://wandb.ai/rap/text2image-fine-tune/runs/gmytjhpi
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230616_155033-gmytjhpi/logs
# [16:36:25] ERROR    failed (exitcode: 1) local_rank: 0 (pid: 19713)   ]8;id=57767;file:///home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/torch/distributed/elastic/multiprocessing/api.py\api.py]8;;\:]8;id=772296;file:///home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/torch/distributed/elastic/multiprocessing/api.py#672\672]8;;\
#                     of binary:
#                     /home/ryan/miniconda3/envs/msc_diss/bin/python
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/ryan/miniconda3/envs/msc_diss/bin/accelerate:8 in <module>             │
# │                                                                              │
# │   5 from accelerate.commands.accelerate_cli import main                      │
# │   6 if __name__ == '__main__':                                               │
# │   7 │   sys.argv[0] = re.sub(r'(-script\.pyw|\.exe)?$', '', sys.argv[0])     │
# │ ❱ 8 │   sys.exit(main())                                                     │
# │   9                                                                          │
# │                                                                              │
# │ /home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/accelerate/ │
# │ commands/accelerate_cli.py:45 in main                                        │
# │                                                                              │
# │   42 │   │   exit(1)                                                         │
# │   43 │                                                                       │
# │   44 │   # Run                                                               │
# │ ❱ 45 │   args.func(args)                                                     │
# │   46                                                                         │
# │   47                                                                         │
# │   48 if __name__ == "__main__":                                              │
# │                                                                              │
# │ /home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/accelerate/ │
# │ commands/launch.py:926 in launch_command                                     │
# │                                                                              │
# │   923 │   │   if mp_from_config_flag:                                        │
# │   924 │   │   │   args.deepspeed_fields_from_accelerate_config.append("mixed │
# │   925 │   │   args.deepspeed_fields_from_accelerate_config = ",".join(args.d │
# │ ❱ 926 │   │   deepspeed_launcher(args)                                       │
# │   927 │   elif args.use_fsdp and not args.cpu:                               │
# │   928 │   │   multi_gpu_launcher(args)                                       │
# │   929 │   elif args.use_megatron_lm and not args.cpu:                        │
# │                                                                              │
# │ /home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/accelerate/ │
# │ commands/launch.py:671 in deepspeed_launcher                                 │
# │                                                                              │
# │   668 │   │   )                                                              │
# │   669 │   │   with patch_environment(**current_env):                         │
# │   670 │   │   │   try:                                                       │
# │ ❱ 671 │   │   │   │   distrib_run.run(args)                                  │
# │   672 │   │   │   except Exception:                                          │
# │   673 │   │   │   │   if is_rich_available() and debug:                      │
# │   674 │   │   │   │   │   console = get_console()                            │
# │                                                                              │
# │ /home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/torch/distr │
# │ ibuted/run.py:785 in run                                                     │
# │                                                                              │
# │   782 │   │   )                                                              │
# │   783 │                                                                      │
# │   784 │   config, cmd, cmd_args = config_from_args(args)                     │
# │ ❱ 785 │   elastic_launch(                                                    │
# │   786 │   │   config=config,                                                 │
# │   787 │   │   entrypoint=cmd,                                                │
# │   788 │   )(*cmd_args)                                                       │
# │                                                                              │
# │ /home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/torch/distr │
# │ ibuted/launcher/api.py:134 in __call__                                       │
# │                                                                              │
# │   131 │   │   self._entrypoint = entrypoint                                  │
# │   132 │                                                                      │
# │   133 │   def __call__(self, *args):                                         │
# │ ❱ 134 │   │   return launch_agent(self._config, self._entrypoint, list(args) │
# │   135                                                                        │
# │   136                                                                        │
# │   137 def _get_entrypoint_name(                                              │
# │                                                                              │
# │ /home/ryan/miniconda3/envs/msc_diss/lib/python3.10/site-packages/torch/distr │
# │ ibuted/launcher/api.py:250 in launch_agent                                   │
# │                                                                              │
# │   247 │   │   │   # if the error files for the failed children exist         │
# │   248 │   │   │   # @record will copy the first error (root cause)           │
# │   249 │   │   │   # to the error file of the launcher process.               │
# │ ❱ 250 │   │   │   raise ChildFailedError(                                    │
# │   251 │   │   │   │   name=entrypoint_name,                                  │
# │   252 │   │   │   │   failures=result.failures,                              │
# │   253 │   │   │   )                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ChildFailedError:
# ============================================================
# train_text_to_image_lora.py FAILED
# ------------------------------------------------------------
# Failures:
#   <NO_OTHER_FAILURES>
# ------------------------------------------------------------
# Root Cause (first observed failure):
# [0]:
#   time      : 2023-06-16_16:36:25
#   host      : honeyboner
#   rank      : 0 (local_rank: 0)
#   exitcode  : 1 (pid: 19713)
#   error_file: <N/A>
#   traceback : To enable traceback see:
# https://pytorch.org/docs/stable/elastic/errors.html
# ============================================================

# %%
# Inference
import torch
from diffusers import StableDiffusionPipeline, DPMSolverMultistepScheduler

model_base = "runwayml/stable-diffusion-v1-5"

pipe = StableDiffusionPipeline.from_pretrained(model_base, torch_dtype=torch.float16)
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
# Out:
# [2023-06-16 17:28:31,235] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.

# %%
pipe.unet.load_attn_procs("./out")
pipe.to("cuda")

gen = torch.manual_seed(42)
# use half the weights from the LoRA finetuned model and half the weights from the base model

image = pipe(
    "a water type pokemon with no arms or legs", num_inference_steps=25, guidance_scale=7.5, cross_attention_kwargs={"scale": 0}, generator=gen
).images[0]
image.save("inference/water_pokemon_base.png")
# use the weights from the fully finetuned LoRA model

image = pipe("a water type pokemon with no arms or legs", num_inference_steps=25, guidance_scale=7.5).images[0]
image.save("inference/water_pokemon_lora.png")
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.image import imread

def display_images_in_grid(folder_path):
    # Get a list of all image files in the folder
    image_files = [file for file in os.listdir(folder_path) if file.endswith(('.jpg', '.jpeg', '.png', '.gif'))]
    image_files.sort()  # Sort the image files in alphabetical order

    # Set up the grid layout
    num_images = len(image_files)
    num_cols = 2  # Number of columns in the grid
    num_rows = (num_images + num_cols - 1) // num_cols  # Number of rows based on the number of images

    # Create a figure and axis objects
    fig, axs = plt.subplots(num_rows, num_cols, figsize=(12, 8))
        # Adjust the spacing properties
    plt.subplots_adjust(wspace=0, hspace=0)

    # Iterate over the image files and display them in the grid
    for i, image_file in enumerate(image_files):
        # Compute the row and column index of the current image
        row = i // num_cols
        col = i % num_cols

        # Load the image using Matplotlib's imread
        image_path = os.path.join(folder_path, image_file)
        image = imread(image_path)

        # Display the image
        axs[row, col].imshow(image)
        axs[row, col].axis("off")

        # Set the filename as the title
        """ filename = os.path.splitext(image_file)[0]
        axs[row, col].set_title(filename, fontsize=8) """

    # Add column titles
    axs[0, 0].set_title("Base")
    axs[0, 1].set_title("LoRA")

    # Adjust the spacing and layout
    plt.tight_layout()

    # Show the grid of images
    plt.show()

# Specify the folder path where the images are located
folder_path = "./inference/"

# Call the function to display images in a grid
display_images_in_grid(folder_path)
